# %%
import pandas as pd

books = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BDP_TermProject/books_data.csv')
ratings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BDP_TermProject/Books_rating.csv')

# %%
books # 212404 rows × 10 columns
# Out:
#                                                     Title  \
# 0                          Its Only Art If Its Well Hung!
# 1                                Dr. Seuss: American Icon
# 2                   Wonderful Worship in Smaller Churches
# 3                           Whispers of the Wicked Saints
# 4       Nation Dance: Religion, Identity and Cultural ...
# ...                                                   ...
# 212399  The Orphan Of Ellis Island (Time Travel Advent...
# 212400                            Red Boots for Christmas
# 212401                                              Mamaw
# 212402                                  The Autograph Man
# 212403  Student's Solutions Manual for Johnson/Mowry's...
#
#                                               description  \
# 0                                                     NaN
# 1       Philip Nel takes a fascinating look into the k...
# 2       This resource includes twelve principles in un...
# ...

# %%
books.isnull().sum()

# %%
# Title의 Nan 값 1개 삭제. # books 의 PK인 Title Nan이면 데이터로서의 가치가 없다.
books.dropna(subset=['Title'], axis=0, inplace=True)

# %%
books.isnull().sum()
# Out:
# Title                 0
# description       68441
# authors           31413
# image             52075
# previewLink       23836
# publisher         75885
# publishedDate     25305
# infoLink          23836
# categories        41198
# ratingsCount     162652
# dtype: int64

# %%
books['Title'].nunique()

# Title에서 Nan 값 1개 row 삭제 후,
#'Title'의 212403 rows 중 unique한 것의 갯수는 212403개.
# 즉, 모든 행은 고유의 값을 가지고 있다. 중복되는 Title이 존재하지 않는다.
# Out:
# 212403

# %%
# 212403개의 row 중, ratingsCount(averaging rating for book) 162652개 존재한다.
# 너무 많이 없네. # ratings테이블에서 가져와서 계산이 가능하다 추가해도 좋을 듯.

# %%
ratings
# Out:
#                  Id                           Title  Price         User_id  \
# 0        1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1        0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2        0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3        0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4        0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
# ...             ...                             ...    ...             ...
# 2999995  B000NSLVCU             The Idea of History    NaN             NaN
# 2999996  B000NSLVCU             The Idea of History    NaN  A1SMUB9ASL5L9Y
# 2999997  B000NSLVCU             The Idea of History    NaN  A2AQMEKZKK5EE4
# 2999998  B000NSLVCU             The Idea of History    NaN  A18SQGYBKS852K
# 2999999  B000NSLVCU             The Idea of History    NaN             NaN
#
# ...

# %%
ratings.isnull().sum()
# Out:
# Id                          0
# Title                     208
# Price                 2518829
# User_id                561787
# profileName            561886
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary             38
# review/text                 8
# dtype: int64

# %%
ratings['Id'].value_counts()
# (Book Id) 'B000IEZE3G'가 6796개로 가장 많고, 뒤따라 여러 책이 많은 수의 리뷰를 가지고 있다.
# Out:
# B000IEZE3G    6796
# B000ILIJE0    4438
# B000GQG7D2    4428
# B000GQG5MA    4427
# B000NDSX6C    4426
#               ...
# B000855WQ4       1
# B000Q390E8       1
# 0967826330       1
# 025201684X       1
# 1882931173       1
# Name: Id, Length: 221998, dtype: int64

# %%
# 책을 추천하기 위해서는 책의 Title이 꼭 필요하므로, rating에서 'Title'이 Nan인 값 삭제
ratings.dropna(subset=['Title'], axis=0, inplace=True)

# %%
ratings['Title'].nunique()
# 212403개의 Unique한 Book Title이 존재한다. # 즉, 많은 수의 책 리뷰가 있다.
# Out:
# 212403

# %%
ratings['User_id'].nunique()
# 1008972개의 Unique한 (rating을 부여한) User가 존재한다. # 즉, 많은 수의 user가 있다.
# Out:
# 1008972

# %%
ratings['User_id'].value_counts()
# Out:
# A14OJS0VWMOSWO    5795
# AFVQZQ8PW0L       3606
# A1D2C0WDCSHUWZ    3146
# AHD101501WCN1     1995
# A1X8VZWTOG8IS6    1804
#                   ...
# A1DVHZFOA7SLCV       1
# A2V8PZ1JVYYHXC       1
# A1BDK3CZP7RU0K       1
# A3CS4YIHR7RJL8       1
# A18SQGYBKS852K       1
# Name: User_id, Length: 1008972, dtype: int64

# %%
# review/helpfulness
ratings['review/helpfulness'].nunique()
# Nan값 없이, 12084개의 unique한 값들로 이루어져 있다.
# Out:
# 12084

# %%
# review/helpfulness의 값들의 갯수
ratings['review/helpfulness'].value_counts()
# Out:
# 0/0        885732
# 1/1        313000
# 2/2        156303
# 0/1        127865
# 1/2         99244
#             ...
# 653/656         1
# 222/446         1
# 605/612         1
# 61/210          1
# 208/233         1
# Name: review/helpfulness, Length: 12084, dtype: int64

# %%
# review/score plot
ratings['review/score'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# review/summary가 Nan인 row 삭제
ratings.dropna(subset=['review/summary'], axis=0, inplace=True)

# %%
# review/text가 Nan인 row 삭제
ratings.dropna(subset=['review/text'], axis=0, inplace=True)

# %%
ratings.isnull().sum()
# Title의 Nan 값 208개 삭제됨.
# review/summary의 Nan 값 38개 삭제됨.
# review/text의 Nan 값 8개 삭제.
# Out:
# Id                          0
# Title                       0
# Price                 2518591
# User_id                561758
# profileName            561853
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary              0
# review/text                 0
# dtype: int64
